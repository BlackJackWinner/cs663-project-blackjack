# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np

# %%
#normal
env = Blackjack3DecksEnv( natural=True)

# %%
import gym
import matplotlib.pyplot as plt
from q_learning import QLAgent
agent = QLAgent(env=env, epsilon=1.0, learning_rate=0.01, gamma=0.01, num_episodes_to_train=30000)

num_rounds = 1000 # Payout calculated over num_rounds
num_samples = 1000 # num_rounds simulated over num_samples

average_payouts = []

observation = env.reset()
for sample in range(num_samples):
    round = 1
    total_payout = 0 # to store total payout over 'num_rounds'
    # Take action based on Q-table of the agent and learn based on that until 'num_episodes_to_train' = 0
    while round <= num_rounds:
        action = agent.choose_action(observation)
        next_observation, payout, is_done, _ = env.step(action)
        agent.learn(observation, action, payout, next_observation)
        total_payout += payout
        observation = next_observation
        if is_done:
            observation = env.reset() # Environment deals new cards to player and dealer
            round += 1
    average_payouts.append(total_payout)
    

# Plot payout per 1000 episodes for episode
plt.plot(average_payouts)           
plt.xlabel('num_samples')
plt.ylabel('payout after 1000 rounds')
plt.show()      
    
print ("Average payout after {} rounds is {}".format(num_rounds, sum(average_payouts)/(num_samples)))
# Out:
# Average payout after 1000 rounds is 342.395

# %%
kaggle_winner_data = pd.read_csv('kaggle_test_env.csv')
kaggle_winner_data
# Out:
#         Unnamed: 0  Unnamed: 0.1 PlayerNo  card1  card2  card3  card4  card5  \
# 0                0             0  Player1      7     10      0      0      0
# 1                6             0  Player1     10      4      0      0      0
# 2               12             0  Player1     10      2      0      0      0
# 3               36             0  Player1      5      9      0      0      0
# 4               42             0  Player1      6      7      0      0      0
# ...            ...           ...      ...    ...    ...    ...    ...    ...
# 112188      899940             0  Player1     10     10      0      0      0
# 112189      899970             0  Player1     10     10      0      0      0
# 112190      899982             0  Player1     10     11      0      0      0
# 112191      899988             0  Player1     10      9      0      0      0
# 112192      899994             0  Player1     10     10      0      0      0
#
# ...

# %%
ply_test = kaggle_winner_data.loc[:,['card1','card2','card3','card4','card5']]

# %%
dl_test = kaggle_winner_data.loc[:,['dealcard1','dealcard2','dealcard3','dealcard4','dealcard5']]

# %%
# def __init__(self, ply_deck=False, dl_deck=False, game_round=False, has_df=False, natural=False)
from blackjack3decks_env import *
from q_learning import *
test_env = Blackjack3DecksEnv(ply_deck=ply_test.to_numpy(), dl_deck=dl_test.to_numpy(), game_round=0, has_df=True)

import gym

import matplotlib.pyplot as plt

#agent = Agent(env=test_env, epsilon=1.0, alpha=0.01, gamma=0.01, num_episodes_to_train=30000)

num_rounds = 1000 # Payout calculated over num_rounds

average_payouts = []

observation = test_env.reset()

round = 1
total_payout = 0 # to store total payout over 'num_rounds'
    # Take action based on Q-table of the agent and learn based on that until 'num_episodes_to_train' = 0
while round <= num_rounds:
    action = agent.choose_action(observation)
    next_observation, payout, is_done, _ = test_env.step(action)
#     agent.learn(observation, action, payout, next_observation)
    total_payout += payout
    observation = next_observation
    if is_done:
        round += 1
        observation = test_env.reset() # Environment deals new cards to player and dealer
    average_payouts.append(total_payout)
    
# Plot payout per 1000 episodes for episode
plt.plot(average_payouts)           
plt.xlabel('num_samples')
plt.ylabel('payout after 1000 rounds')
plt.show()      
    
#print ("Average payout after {} rounds is {}".format(num_rounds, sum(average_payouts)/(num_samples)))

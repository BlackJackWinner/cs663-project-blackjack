# %%
import pandas as pd
import numpy as np
df = pd.read_csv('blkjckhands.csv', sep=',')
df
# Out:
#         Unnamed: 0 PlayerNo  card1  card2  card3  card4  card5  sumofcards  \
# 0                0  Player1      7     10      0      0      0          17
# 1                1  Player2     10      9      0      0      0          19
# 2                2  Player3      9      8      0      0      0          17
# 3                3  Player4      2     10      0      5      0          17
# 4                4  Player5     10      2      0      5      0          17
# ...            ...      ...    ...    ...    ...    ...    ...         ...
# 899995           1  Player2     10      7      0      0      0          17
# 899996           2  Player3      6      1     10      0      0          17
# 899997           3  Player4      4      2      9      0      0          15
# 899998           4  Player5      9     10      0      0      0          19
# 899999           5  Player6      5     10      0      0      0          15
#
#         dealcard1  dealcard2  ...  dealcard4  dealcard5  sumofdeal  blkjck  \
# 0              10          8  ...          0          0         18   nowin
# 1              10          8  ...          0          0         18   nowin
# 2              10          8  ...          0          0         18   nowin
# 3              10          8  ...          0          0         18   nowin
# 4              10          8  ...          0          0         18   nowin
# ...           ...        ...  ...        ...        ...        ...     ...
# 899995          3          9  ...          2          0         18   nowin
# 899996          3          9  ...          2          0         18   nowin
# 899997          3          9  ...          2          0         18   nowin
# 899998          3          9  ...          2          0         18   nowin
# 899999          3          9  ...          2          0         18   nowin
#
#        winloss plybustbeat dlbustbeat plwinamt  dlwinamt  ply2cardsum
# 0         Loss        Beat      Dlwin        0        10           17
# 1          Win       Plwin       Beat       20         0           19
# 2         Loss        Beat      Dlwin        0        10           17
# 3         Loss        Beat      Dlwin        0        10           12
# 4         Loss        Beat      Dlwin        0        10           12
# ...        ...         ...        ...      ...       ...          ...
# 899995    Loss        Beat      Dlwin        0        10           17
# 899996    Loss        Beat      Dlwin        0        10            7
# 899997    Loss        Beat      Dlwin        0        10            6
# 899998     Win       Plwin       Beat       20         0           19
# 899999    Loss        Beat      Dlwin        0        10           15
#
# [900000 rows x 21 columns]

# %%
df.describe()
# Out:
#           Unnamed: 0          card1          card2          card3  \
# count  900000.000000  900000.000000  900000.000000  900000.000000
# mean        2.500000       7.126259       7.089927       1.955088
# std         1.707826       2.994719       3.008032       3.531830
# min         0.000000       1.000000       1.000000       0.000000
# 25%         1.000000       5.000000       4.000000       0.000000
# 50%         2.500000       8.000000       8.000000       0.000000
# 75%         4.000000      10.000000      10.000000       2.000000
# max         5.000000      11.000000      11.000000      11.000000
#
#                card4          card5     sumofcards      dealcard1  \
# count  900000.000000  900000.000000  900000.000000  900000.000000
# mean        2.336462       0.389787      18.897522       7.170380
# std         3.657284       1.730740       3.210611       2.981575
# min         0.000000       0.000000       8.000000       1.000000
# 25%         0.000000       0.000000      17.000000       5.000000
# 50%         0.000000       0.000000      19.000000       8.000000
# 75%         4.000000       0.000000      21.000000      10.000000
# max        10.000000      10.000000      26.000000      11.000000
#
#            dealcard2      dealcard3      dealcard4      dealcard5  \
# count  900000.000000  900000.000000  900000.000000  900000.000000
# mean        7.129867       4.391293       1.380733       0.226433
# std         2.990306       4.080103       3.038298       1.334263
# min         1.000000       0.000000       0.000000       0.000000
# 25%         5.000000       0.000000       0.000000       0.000000
# 50%         8.000000       4.000000       0.000000       0.000000
# 75%        10.000000       9.000000       0.000000       0.000000
# max        11.000000      11.000000      10.000000      10.000000
#
#            sumofdeal       plwinamt       dlwinamt    ply2cardsum
# count  900000.000000  900000.000000  900000.000000  900000.000000
# mean       20.298707       9.723528       4.775789      14.216186
# std         2.556207       9.789798       4.994973       4.429873
# min         8.000000       0.000000       0.000000       2.000000
# 25%        18.000000       0.000000       0.000000      12.000000
# 50%        20.000000      10.000000       0.000000      14.000000
# 75%        22.000000      20.000000      10.000000      18.000000
# max        26.000000      25.000000      10.000000      21.000000

# %%
df['valid?'] = df.apply(lambda x: 0 if df['card3']== 0 and (df['card4']!=0 or df['card5']!=0) else 1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-87ccecb4afdd> in <module>
# ----> 1 df['valid?'] = df.apply(lambda x: 0 if df['card3']== 0 and (df['card4']!=0 or df['card5']!=0) else 1)
#       2
#
# ~/opt/anaconda3/envs/gym/lib/python3.6/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    6876             kwds=kwds,
#    6877         )
# -> 6878         return op.get_result()
#    6879
#    6880     def applymap(self, func) -> "DataFrame":
#
# ~/opt/anaconda3/envs/gym/lib/python3.6/site-packages/pandas/core/apply.py in get_result(self)
#     184             return self.apply_raw()
#     185
# --> 186         return self.apply_standard()
#     187
#     188     def apply_empty_result(self):
#
# ~/opt/anaconda3/envs/gym/lib/python3.6/site-packages/pandas/core/apply.py in apply_standard(self)
#     294             try:
#     295                 result = libreduction.compute_reduction(
# --> 296                     values, self.f, axis=self.axis, dummy=dummy, labels=labels
#     297                 )
#     298             except ValueError as err:
#
# pandas/_libs/reduction.pyx in pandas._libs.reduction.compute_reduction()
#
# pandas/_libs/reduction.pyx in pandas._libs.reduction.Reducer.get_result()
#
# <ipython-input-26-87ccecb4afdd> in <lambda>(x)
# ----> 1 df['valid?'] = df.apply(lambda x: 0 if df['card3']== 0 and (df['card4']!=0 or df['card5']!=0) else 1)
#       2
#
# ~/opt/anaconda3/envs/gym/lib/python3.6/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1477     def __nonzero__(self):
#    1478         raise ValueError(
# -> 1479             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1480             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1481         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
df.groupby(['PlayerNo'])['plwinamt'].sum()
# Out:
# PlayerNo
# Player1    1460415
# Player2    1458320
# Player3    1455900
# Player4    1458430
# Player5    1456025
# Player6    1462085
# Name: plwinamt, dtype: int64

# %%
sp = df.loc[df['plwinamt'] == 10]
sp
# Out:
#         Unnamed: 0 PlayerNo  card1  card2  card3  card4  card5  sumofcards  \
# 27               3  Player4      2      9      8      0      0          19
# 49               1  Player2      3      2      5     10      0          20
# 51               3  Player4      5      9      0      6      0          20
# 65               5  Player6      5      6      8      0      0          19
# 70               4  Player5     11     10      0      0      0          21
# ...            ...      ...    ...    ...    ...    ...    ...         ...
# 899969           5  Player6     10      4      0      3      0          17
# 899972           2  Player3      4      5     10      0      0          19
# 899989           1  Player2      3     10      0      8      0          21
# 899991           3  Player4      9      2     10      0      0          21
# 899993           5  Player6      8      3     10      0      0          21
#
#         dealcard1  dealcard2  ...  dealcard4  dealcard5  sumofdeal  blkjck  \
# 27              8          7  ...          0          0         19   nowin
# 49             10         10  ...          0          0         20   nowin
# 51             10         10  ...          0          0         20   nowin
# 65             10          5  ...          0          0         19   nowin
# 70             10         11  ...          0          0         21     Win
# ...           ...        ...  ...        ...        ...        ...     ...
# 899969         11          6  ...          0          0         17   nowin
# 899972          6          9  ...          0          0         19   nowin
# 899989         10          2  ...          0          0         21   nowin
# 899991         10          2  ...          0          0         21   nowin
# 899993         10          2  ...          0          0         21   nowin
#
#        winloss plybustbeat dlbustbeat plwinamt  dlwinamt  ply2cardsum
# 27        Push        Push       Push       10         0           11
# 49        Push        Push       Push       10         0            5
# 51        Push        Push       Push       10         0           14
# 65        Push        Push       Push       10         0           11
# 70        Push        Push       Push       10         0           21
# ...        ...         ...        ...      ...       ...          ...
# 899969    Push        Push       Push       10         0           14
# 899972    Push        Push       Push       10         0            9
# 899989    Push        Push       Push       10         0           13
# 899991    Push        Push       Push       10         0           11
# 899993    Push        Push       Push       10         0           11
#
# [84233 rows x 21 columns]

# %%
df.groupby(['PlayerNo'])['plwinamt'].sum().idxmax()
# Out:
# 'Player6'

# %%
ply6_df = df.loc[df['PlayerNo'] == 'Player6']
ply6_df
# Out:
#         Unnamed: 0 PlayerNo  card1  card2  card3  card4  card5  sumofcards  \
# 5                5  Player6      6      1      8     10      0          25
# 11               5  Player6      3      5      2      4      0          14
# 17               5  Player6      9      5      0      0      0          14
# 23               5  Player6      4      8      0     10      0          22
# 29               5  Player6      9      3      0      6      0          18
# ...            ...      ...    ...    ...    ...    ...    ...         ...
# 899975           5  Player6      2      3      8      0      0          13
# 899981           5  Player6      9     10      0      0      0          19
# 899987           5  Player6      4      5     10      0      0          19
# 899993           5  Player6      8      3     10      0      0          21
# 899999           5  Player6      5     10      0      0      0          15
#
#         dealcard1  dealcard2  ...  dealcard4  dealcard5  sumofdeal  blkjck  \
# 5              10          8  ...          0          0         18   nowin
# 11              4          4  ...         10          0         23   nowin
# 17              4          6  ...         10          0         26   nowin
# 23             10          8  ...          0          0         18   nowin
# 29              8          7  ...          0          0         19   nowin
# ...           ...        ...  ...        ...        ...        ...     ...
# 899975          6          9  ...          0          0         19   nowin
# 899981         11         10  ...          0          0         21   nowin
# 899987          6         10  ...          0          0         26   nowin
# 899993         10          2  ...          0          0         21   nowin
# 899999          3          9  ...          2          0         18   nowin
#
#        winloss plybustbeat dlbustbeat plwinamt  dlwinamt  ply2cardsum
# 5         Loss        Bust     PlBust        0        10            7
# 11         Win      DlBust       Bust       20         0            8
# 17         Win      DlBust       Bust       20         0           14
# 23        Loss        Bust     PlBust        0        10           12
# 29        Loss        Beat      Dlwin        0        10           12
# ...        ...         ...        ...      ...       ...          ...
# 899975    Loss        Beat      Dlwin        0        10            5
# 899981    Loss        Beat      Dlwin        0        10           19
# 899987     Win      DlBust       Bust       20         0            9
# 899993    Push        Push       Push       10         0           11
# 899999    Loss        Beat      Dlwin        0        10           15
#
# [150000 rows x 21 columns]

# %%
ply_test = ply6_df.loc[:,['card1','card2','card3','card4','card5']]

# %%
dl_test = ply6_df.loc[:,['dealcard1','dealcard2','dealcard3','dealcard4','dealcard5']]
